# %%
pip install geocoder
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Requirement already satisfied: click in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: requests in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from geocoder) (2.25.1)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: decorator in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ratelim->geocoder) (5.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->geocoder) (1.26.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->geocoder) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->geocoder) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->geocoder) (2.10)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=c7321262333ba0c76eeb7b70782ca93686eafbf63fb1a2d72a8df7e164feb281
#   Stored in directory: c:\users\katoh\appdata\local\pip\cache\wheels\8e\70\28\3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4
# Successfully built future
# Installing collected packages: ratelim, future, geocoder
# Successfully installed future-0.18.2 geocoder-1.38.1 ratelim-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.3 soupsieve-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: numpy in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium) (1.20.3)
# Requirement already satisfied: requests in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium) (2.25.1)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium) (2021.5.30)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit-folium
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit-folium in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (0.4.0)
# Requirement already satisfied: streamlit>=0.79 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit-folium) (0.82.0)
# Requirement already satisfied: folium>=0.11 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit-folium) (0.12.1)
# Requirement already satisfied: numpy in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium>=0.11->streamlit-folium) (1.20.3)
# Requirement already satisfied: jinja2>=2.9 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium>=0.11->streamlit-folium) (3.0.1)
# Requirement already satisfied: requests in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium>=0.11->streamlit-folium) (2.25.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from folium>=0.11->streamlit-folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jinja2>=2.9->folium>=0.11->streamlit-folium) (2.0.1)
# Requirement already satisfied: validators in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (0.18.2)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (1.2.4)
# Requirement already satisfied: blinker in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (1.4)
# Requirement already satisfied: packaging in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (20.9)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (0.6.2)
# Requirement already satisfied: altair>=3.2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (4.1.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (3.17.1)
# Requirement already satisfied: python-dateutil in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (2.8.1)
# Requirement already satisfied: cachetools>=4.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (4.2.2)
# Requirement already satisfied: watchdog in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (2.1.2)
# Requirement already satisfied: astor in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (0.8.1)
# Requirement already satisfied: tornado>=5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (6.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (8.2.0)
# Requirement already satisfied: gitpython in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (3.1.17)
# Requirement already satisfied: tzlocal in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (2.1)
# Requirement already satisfied: pyarrow in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (4.0.1)
# Requirement already satisfied: toml in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (0.10.2)
# Requirement already satisfied: base58 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (2.1.0)
# Requirement already satisfied: click<8.0,>=7.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from streamlit>=0.79->streamlit-folium) (7.1.2)
# Requirement already satisfied: jsonschema in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from altair>=3.2.0->streamlit>=0.79->streamlit-folium) (3.2.0)
# Requirement already satisfied: toolz in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from altair>=3.2.0->streamlit>=0.79->streamlit-folium) (0.11.1)
# Requirement already satisfied: entrypoints in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from altair>=3.2.0->streamlit>=0.79->streamlit-folium) (0.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pandas>=0.21.0->streamlit>=0.79->streamlit-folium) (2021.1)
# Requirement already satisfied: six>=1.9 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from protobuf!=3.11,>=3.6.0->streamlit>=0.79->streamlit-folium) (1.16.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (7.6.3)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.5.5)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.0.5)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (7.24.0)
# Requirement already satisfied: jupyter-client in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (6.1.12)
# Requirement already satisfied: jedi>=0.16 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (3.0.18)
# Requirement already satisfied: matplotlib-inline in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.1.2)
# Requirement already satisfied: pickleshare in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (52.0.0.post20210125)
# Requirement already satisfied: pygments in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (2.9.0)
# Requirement already satisfied: backcall in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.2.0)
# Requirement already satisfied: colorama in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.4.4)
# Requirement already satisfied: decorator in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.0.9)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (3.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.8.2)
# Requirement already satisfied: jupyter-core in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (4.7.1)
# Requirement already satisfied: ipython-genutils in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit>=0.79->streamlit-folium) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jsonschema->altair>=3.2.0->streamlit>=0.79->streamlit-folium) (0.17.3)
# Requirement already satisfied: wcwidth in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (6.4.0)
# Requirement already satisfied: argon2-cffi in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (20.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (22.1.0)
# Requirement already satisfied: prometheus-client in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.5.0)
# Requirement already satisfied: nbconvert in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.10.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (301)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (2.20)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from gitpython->streamlit>=0.79->streamlit-folium) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->streamlit>=0.79->streamlit-folium) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.8.4)
# Requirement already satisfied: testpath in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.4.3)
# Requirement already satisfied: bleach in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.5.3)
# Requirement already satisfied: nest-asyncio in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.5.1)
# Requirement already satisfied: async-generator in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.10)
# Requirement already satisfied: webencodings in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from packaging->streamlit>=0.79->streamlit-folium) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium>=0.11->streamlit-folium) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium>=0.11->streamlit-folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium>=0.11->streamlit-folium) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from requests->folium>=0.11->streamlit-folium) (1.26.5)

# %%
pip install pydeck
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pydeck in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (0.6.2)
# Requirement already satisfied: jinja2>=2.10.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck) (3.0.1)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck) (1.20.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck) (5.0.5)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from pydeck) (5.5.5)
#
# Requirement already satisfied: jupyter-client in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipykernel>=5.1.2->pydeck) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipykernel>=5.1.2->pydeck) (6.1)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipykernel>=5.1.2->pydeck) (7.24.0)
# Requirement already satisfied: pickleshare in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.18.0)
# Requirement already satisfied: pygments in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (2.9.0)
# Requirement already satisfied: colorama in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.4.4)
# Requirement already satisfied: decorator in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (3.0.18)
# Requirement already satisfied: setuptools>=18.5 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (52.0.0.post20210125)
# Requirement already satisfied: matplotlib-inline in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.1.2)
# Requirement already satisfied: backcall in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipywidgets>=7.0.0->pydeck) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipywidgets>=7.0.0->pydeck) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from ipywidgets>=7.0.0->pydeck) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jinja2>=2.10.1->pydeck) (2.0.1)
# Requirement already satisfied: ipython-genutils in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (21.2.0)
# Requirement already satisfied: wcwidth in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (6.4.0)
# Requirement already satisfied: argon2-cffi in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.10.0)
# Requirement already satisfied: prometheus-client in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (22.1.0)
# Requirement already satisfied: nbconvert in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (6.0.7)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jupyter-client->ipykernel>=5.1.2->pydeck) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck) (301)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (2.20)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.5.3)
# Requirement already satisfied: bleach in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (3.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.7.1)
# Requirement already satisfied: testpath in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.1.2)
# Requirement already satisfied: async-generator in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (1.5.1)
# Requirement already satisfied: packaging in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (20.9)
# Requirement already satisfied: webencodings in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\katoh\anaconda3\envs\web_app\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck) (2.4.7)

# %%
pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.61.1-py2.py3-none-any.whl (75 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.61.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)Note: you may need to restart the kernel to use updated packages.
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0

# %%
import streamlit as st
import pandas as pd
import requests
import geocoder

# %%
#@st.cache
def get_inf_con(url):
    df = pd.read_csv(url, encoding='utf-8')
    #df = pd.DataFrame(df)
    return df

url ='https://www.opendata.metro.tokyo.lg.jp/soumu/130001_evacuation_center.csv'
df_eva = get_inf_con(url)

# %%
df_eva
# Out:
#          避難所_名称  地方公共団体コード 都道府県 指定区市町村名                 住所         緯度  \
# 0         麹町小学校     131016  東京都    千代田区       東京都千代田区麹町2-8  35.685344
# 1         番町小学校     131016  東京都    千代田区        東京都千代田区六番町8  35.687975
# 2         麹町中学校     131016  東京都    千代田区    東京都千代田区平河町2-5-1  35.680494
# 3       富士見みらい館     131016  東京都    千代田区   東京都千代田区富士見1-10-3  35.697237
# 4       お茶の水小学校     131016  東京都    千代田区  東京都千代田区神田猿楽町1-1-1  35.697358
# ...         ...        ...  ...     ...                ...        ...
# 2631   扇浦交流センター     134210  東京都    小笠原村       東京都小笠原村父島字扇浦  27.071064
# 2632   奥村交流センター     134210  東京都    小笠原村       東京都小笠原村父島字奥村  27.098758
# 2633       母島支所     134210  東京都    小笠原村       東京都小笠原村母島字元地  26.641756
# 2634      母島診療所     134210  東京都    小笠原村       東京都小笠原村母島字元地  26.641551
# 2635  母島小中学校体育館     134210  東京都    小笠原村       東京都小笠原村母島字元地  26.641961
#
#               経度
# 0     139.739763
# 1     139.733800
# 2     139.739246
# 3     139.746433
# 4     139.760306
# ...          ...
# 2631  142.202905
# 2632  142.207774
# 2633  142.158992
# 2634  142.158550
# 2635  142.160018
#
# [2636 rows x 7 columns]

# %%
"""
# "東京都の協力要請に従う店舗'
東京都感染対策協力店
"""

st.write(df_inf_con)

# %%
print(df_eva.columns.get_loc('緯度'))
print(df_eva.columns.get_loc('経度'))
# Out:
# 5
# 6

# %% [markdown]
# ## ジオコーダーの定義

# %%
from bs4 import BeautifulSoup
import time
#from tqdm import tqdm

def get_eva_location(eva_location):
    latlons = []
    for location in eva_location:
            lat = location[:, 0]
            lon = location[:, 1]
            latlons.append([lat,lon])
    return latlons

# %%
eva_location = df_eva.iloc[:, 5:6]

df_geo = pd.DataFrame(get_eva_location(eva_location))
df_geo = df_geo.set_axis(['lat', 'lon'], axis=1)
df_geo
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-5d16d2c3f2e4> in <module>
#       1 eva_location = df_eva.iloc[:, 5:6]
#       2
# ----> 3 df_geo = pd.DataFrame(get_eva_location(eva_location))
#       4 df_geo = df_geo.set_axis(['lat', 'lon'], axis=1)
#       5 df_geo
#
# <ipython-input-76-6bebbc439164> in get_eva_location(eva_location)
#       6     latlons = []
#       7     for location in eva_location:
# ----> 8             lat = location[:, 0]
#       9             lon = location[:, 1]
#      10             latlons.append([lat,lon])
#
# TypeError: string indices must be integers

# %%
df_geo = pd.DataFrame(shop_geo)
df_geo = df_geo.set_axis(['lat', 'lon'], axis=1)
df_geo
# Out:
#           lat         lon
# 0   35.703778    139.6171
# 1   35.714788  139.860588
# 2   35.720976  139.668069
# 3    35.70054  139.372117
# 4   35.692202  139.837642
# 5   35.655584  139.652714
# 6   35.725843   139.71405
# 7   35.693661  139.619733
# 8   35.747159  139.719056
# 9     35.5159   139.48039
# 10  35.657694  139.727385
# 11  35.762927  139.845002
# 12  35.680715  139.771149
# 13  35.657102  139.718036
# 14  35.717568  139.792918
# 15  35.777213  139.786948
# 16  35.735881  139.725296
# 17  35.570946  139.686122
# 18  35.643119   139.28547
# 19  35.755703  139.694988
# 20  35.746413   139.67842
# 21  35.712847  139.705502
# 22  35.646374  139.720068
# 23  35.649604  139.681984
# 24  35.713644  139.818054
# 25   35.61105  139.741475
# 26  35.705532  139.637429
# 27  35.662013  139.702644
# 28   35.70884   139.63474
# 29   35.65913  139.699191
# 30  35.566521  139.727749
# 31  35.629196  139.448273
# 32  35.711816  139.791415
# 33  35.738129  139.489349
# 34  35.706946  139.775176
# 35   35.67141  139.740013
# 36  35.673071  139.795005
# 37  35.712872  139.701113
# 38  35.695848  139.774076
# 39  35.703558  139.603787
# 40  35.721774  139.479834
# 41  35.727759  139.437675
# 42  35.667087  139.745524
# 43  35.656739  139.695262
# 44  35.632417   139.69246
# 45  35.571225  139.726276
# 46  35.778268  139.783818

# %% [markdown]
# ## 元のデータフレームにconcat

# %%
import folium
import pandas as pd

# このCSVには、県庁所在地の緯度・経度がlatitudeカラムとlongitudeカラムに入っている。
#df_prefecture = pd.read_csv(" https://www.opendata.metro.tokyo.lg.jp/soumu/130001_evacuation_center.csv")

def visualize_locations(df,  zoom=4):
    """日本を拡大した地図に、pandasデータフレームのlatitudeおよびlongitudeカラムをプロットする。
    """
        	
    # 図の大きさを指定する。
    f = folium.Figure(width=1000, height=500)

    # 初期表示の中心の座標を指定して地図を作成する。
    center_lat=34.686567
    center_lon=135.52000
    m = folium.Map([center_lat,center_lon], zoom_start=zoom).add_to(f)
        
    # データフレームの全ての行のマーカーを作成する。
    for i in range(0,len(df)):
        folium.Marker(location=[df["緯度"][i],df["経度"][i]]).add_to(m)
        
    return m
    
visualize_locations(df_eva)
# Out:
# <iframe src="about:blank" width="1000" height="500"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7dd05a0fa8e44de4bb2e77407b0d0209%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7dd05a0fa8e44de4bb2e77407b0d0209%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7dd05a0fa8e44de4bb2e77407b0d0209%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7dd05a0fa8e44de4bb2e77407b0d0209%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.686567%2C%20135.52%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%204%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20 ...

# %%
# Out:
#            0           1
# 0  35.655584  139.652714
# 1  35.725843   139.71405
# 2  35.693661  139.619733
# 3  35.747159  139.719056

# %%
import folium
import pandas as pd

# このCSVには、県庁所在地の緯度・経度がlatitudeカラムとlongitudeカラムに入っている。
#df_prefecture = pd.read_csv("../data/prefectural_capital_locations.csv")

def visualize_locations(df,  zoom=4):
    """日本を拡大した地図に、pandasデータフレームのlatitudeおよびlongitudeカラムをプロットする。
    """
        	
    # 図の大きさを指定する。
    f = folium.Figure(width=1000, height=500)

    # 初期表示の中心の座標を指定して地図を作成する。
    center_lat=34.686567
    center_lon=135.52000
    m = folium.Map([center_lat,center_lon], zoom_start=zoom).add_to(f)
        
    # データフレームの全ての行のマーカーを作成する。
    for i in range(0,len(df)):
        folium.Marker(location=[df['lat'][i],df['lon'][i]]).add_to(m)
        
    return m
    
visualize_locations(df_geo)
# Out:
# <iframe src="about:blank" width="1000" height="500"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d6db0417638443e9bd25273a99577cf5%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d6db0417638443e9bd25273a99577cf5%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d6db0417638443e9bd25273a99577cf5%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d6db0417638443e9bd25273a99577cf5%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B34.686567%2C%20135.52%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%204%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20 ...

# %%
pip list
# Out:
# Note: you may need to restart the kernel to use updated packages.Package                                       Version
# --------------------------------------------- -------------------
# altair                                        4.1.0
# anyio                                         2.2.0
# argon2-cffi                                   20.1.0
# astor                                         0.8.1
# async-generator                               1.10
# attrs                                         21.2.0
# azure-cognitiveservices-vision-computervision 0.9.0
# azure-common                                  1.1.27
# Babel                                         2.9.1
#
# backcall                                      0.2.0
# base58                                        2.1.0
# beautifulsoup4                                4.9.3
# bleach                                        3.3.0
# blinker                                       1.4
# branca                                        0.4.2
# brotlipy                                      0.7.0
# cachetools                                    4.2.2
# certifi                                       2021.5.30
# cffi                                          1.14.5
# chardet                                       4.0.0
# click                                         7.1.2
# colorama                                      0.4.4
# cryptography                                  3.4.7
# cycler                                        0.10.0
# decorator                                     5.0.9
# defusedxml                                    0.7.1
# entrypoints                                   0.3
# folium                                        0.12.1
# future                                        0.18.2
# geocoder                                      1.38.1
# gitdb                                         4.0.7
# GitPython                                     3.1.17
# idna                                          2.10
# importlib-metadata                            3.10.0
# ipykernel                                     5.5.5
# ipython                                       7.24.0
# ipython-genutils                              0.2.0
# ipywidgets                                    7.6.3
# isodate                                       0.6.0
# jedi                                          0.18.0
# Jinja2                                        3.0.1
# json5                                         0.9.5
# jsonschema                                    3.2.0
# jupyter-client                                6.1.12
# jupyter-core                                  4.7.1
# jupyter-packaging                             0.7.12
# jupyter-server                                1.4.1
# jupyterlab                                    3.0.14
# jupyterlab-pygments                           0.1.2
# jupyterlab-server                             2.4.0
# jupyterlab-widgets                            1.0.0
# kiwisolver                                    1.3.1
# lxml                                          4.6.3
# MarkupSafe                                    2.0.1
# matplotlib                                    3.4.2
# matplotlib-inline                             0.1.2
# mistune                                       0.8.4
# msrest                                        0.6.21
# multitasking                                  0.0.9
# nbclassic                                     0.2.6
# nbclient                                      0.5.3
# nbconvert                                     6.0.7
# nbformat                                      5.1.3
# nest-asyncio                                  1.5.1
# notebook                                      6.4.0
# numpy                                         1.20.3
# oauthlib                                      3.1.1
# packaging                                     20.9
# pandas                                        1.2.4
# pandocfilters                                 1.4.3
# parso                                         0.8.2
# pickleshare                                   0.7.5
# Pillow                                        8.2.0
# pip                                           21.1.1
# prometheus-client                             0.11.0
# prompt-toolkit                                3.0.18
# protobuf                                      3.17.1
# pyarrow                                       4.0.1
# pycparser                                     2.20
# pydeck                                        0.6.2
# Pygments                                      2.9.0
# pyOpenSSL                                     20.0.1
# pyparsing                                     2.4.7
# pyrsistent                                    0.17.3
# PySocks                                       1.7.1
# python-dateutil                               2.8.1
# pytz                                          2021.1
# pywin32                                       301
# pywinpty                                      1.1.1
# pyzmq                                         22.1.0
# ratelim                                       0.1.6
# requests                                      2.25.1
# requests-oauthlib                             1.3.0
# Send2Trash                                    1.5.0
# setuptools                                    52.0.0.post20210125
# six                                           1.16.0
# smmap                                         4.0.0
# sniffio                                       1.2.0
# soupsieve                                     2.2.1
# streamlit                                     0.82.0
# terminado                                     0.10.0
# testpath                                      0.5.0
# toml                                          0.10.2
# toolz                                         0.11.1
# tornado                                       6.1
# tqdm                                          4.61.1
# traitlets                                     5.0.5
# tzlocal                                       2.1
# urllib3                                       1.26.5
# validators                                    0.18.2
# watchdog                                      2.1.2
# wcwidth                                       0.2.5
# webencodings                                  0.5.1
# wheel                                         0.36.2
# widgetsnbextension                            3.5.1
# win-inet-pton                                 1.1.0
# wincertstore                                  0.2
# yfinance                                      0.1.59
# zipp                                          3.4.1

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent='test')

def get_lat_lon_from_address(shop_address):
    latlons = []
    for address in shop_address:
        location = geolocator.geocode(address)
        lat = location.latitude
        lon = location.longitude
        latlons.append([lat, lon])
            
    return latlons

# %%
for adress in shop_address:
    print(adress)

g = geolocator.geocode('東京都杉並区荻窪５－１６－５')
print(g.latitude)
# Out:
# 東京都杉並区荻窪5-16-5 エルシオン荻窪301
# 東京都葛飾区新小岩1-51-1  ますやビル1 F
# 東京都中野区沼袋1-21-7
# 東京都葛飾区堀切７－２１－１０  1 F
# 東京都昭島市中神町２－３４－３
# 東京都江東区大島7-8-3
# 東京都世田谷区梅丘1-24-13  1 F
# 東京都豊島区南池袋2丁目11-5 三栖ビル1 F
# 東京都杉並区荻窪１-19-11
# 東京都板橋区板橋1-18-5
# 東京都町田市南つくし野2-1-1
# 東京都豊島区南大塚３－５０－３ 　Ｔ・Ｊ大塚ビルＢ１ Ｆ
# 東京都港区元麻布3-2-21 ルミエ-ル元麻布地下１ 階
# 東京都葛飾区亀有4－19－5 渡邊ビル1 F
# 東京都中央区日本橋3-2-17
# 東京都港区南青山7-13-13 フォレストビル1 階
# 東京都台東区浅草3-12-4
# 東京都足立区西新井栄町2-16-10
# 東京都豊島区北大塚3-29-6
# 東京都大田区下丸子3-6-6
# 東京都八王子市初沢町１２２７－８ 夕月ビル1 階
# 東京都板橋区弥生町35-1 東園ビル1 F
# 東京都板橋区小茂根1-21-4
# 東京都新宿区高田馬場1-26-12 高田馬場ビル2 F
# 東京都渋谷区恵比寿2-9-5 リベルタⅢ1 階
# 東京都世田谷区池尻3-19-3
# 東京都墨田区押上３－１０－９
# 東京都品川区南品川5－4－2
# 東京都杉並区阿佐谷北１－４－１１
# 東京都渋谷区渋谷1‐23‐16
# 東京都杉並区阿佐谷北1-35-7
# 東京都練馬区練馬1-5-13 練馬駅前ビル3 F
# 東京都渋谷区道玄坂2-6-2 　藤山恒産道玄坂ビル地下1 階
# 東京都大田区蒲田 2-8-12
# 東京都多摩市永山1-4 　グリナ-ド永山１号館３ F
# 東京都台東区西浅草2－1－4 鈴木ビル202号室
# 東京都小平市美園町2-9-5-2 階
# 東京都台東区上野５－２６－１６
# 東京都港区赤坂2-9-4  赤坂山王ビル2 階
# 東京都江東区門前仲町１－８－８
# 東京都新宿区高田馬場4-13-12
# 東京都千代田区神田須田町2-9-13
# 東京都杉並区西荻南3 ―21－８
# 東京都小平市学園西町2-2-15
# 東京都小平市小川町1-432-1 いなげや小平小川橋店１ F
# 東京都港区虎ノ門2-10-4
# 東京都渋谷区円山町5-5
# 東京都目黒区中町２－４４－１３
# 東京都大田区大森西4-4-15
# 東京都足立区栗原3-10-15  TKSビル
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-2548f6dee1a4> in <module>
#       3
#       4 g = geolocator.geocode('東京都杉並区荻窪５－１６－５')
# ----> 5 print(g.latitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
shop_geo = get_lat_lon_from_address(shop_address)

df_geo = pd.DataFrame(shop_geo)
df_geo = df_geo.set_axis(['lat', 'lon'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-35144d6bad20> in <module>
# ----> 1 shop_geo = get_lat_lon_from_address(shop_address)
#       2
#       3 df_geo = pd.DataFrame(shop_geo)
#       4 df_geo = df_geo.set_axis(['lat', 'lon'], axis=1)
#
# <ipython-input-31-41da49477a13> in get_lat_lon_from_address(shop_address)
#       7     for address in shop_address:
#       8         location = geolocator.geocode(address)
# ----> 9         lat = location.latitude
#      10         lon = location.longitude
#      11         latlons.append([lat, lon])
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
import folium
import pandas as pd

# このCSVには、県庁所在地の緯度・経度がlatitudeカラムとlongitudeカラムに入っている。
#df_prefecture = pd.read_csv("../data/prefectural_capital_locations.csv")

def visualize_locations(df,  zoom=4):
    """日本を拡大した地図に、pandasデータフレームのlatitudeおよびlongitudeカラムをプロットする。
    """
        	
    # 図の大きさを指定する。
    f = folium.Figure(width=1000, height=500)

    # 初期表示の中心の座標を指定して地図を作成する。
    center_lat=34.686567
    center_lon=135.52000
    m = folium.Map([center_lat,center_lon], zoom_start=zoom).add_to(f)
        
    # データフレームの全ての行のマーカーを作成する。
    for i in range(0,len(df)):
        folium.Marker(location=[df['lat'][i],df['lon'][i]]).add_to(m)
        
    return m
    
visualize_locations(df_geo)

# %%
w = df_eva['指定区市町村名'].unique()
w
# Out:
# array(['千代田区', '中央区', '港区', '新宿区', '文京区', '台東区', '墨田区', '江東区', '品川区',
#        '目黒区', '大田区', '世田谷区', '渋谷区', '中野区', '杉並区', '豊島区', '北区', '荒川区',
#        '板橋区', '練馬区', '足立区', '葛飾区', '江戸川区', '八王子市', '立川市', '武蔵野市', '三鷹市',
#        '青梅市', '府中市', '昭島市', '調布市', '町田市', '小金井市', '小平市', '日野市', '東村山市',
#        '国分寺市', '国立市', '福生市', '狛江市', '東大和市', '清瀬市', '東久留米市', '武蔵村山市',
#        '多摩市', '稲城市', '羽村市', 'あきる野市', '西東京市', '瑞穂町', '日の出町', '檜原村', '奥多摩町',
#        '大島町', '利島村', '新島村', '神津島村', '三宅村', '御蔵島村', '八丈町', '青ヶ島村', '小笠原村'],
#       dtype=object)
